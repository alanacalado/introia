# %% [markdown]
# " Minha vovó Cecilia Lima (in memoriam) sempre dizia:"
# - Esse computador só falta falar.

# %% [markdown]
# # PLN - Processamento de Linguagem Natural

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Engenheiro de IA
# - Texto( Dados Não Estruturados) - EDA
# - Data mining (Text mining) - TDM
# - Onde minerar texto :
# * E-mails
# * Transcrições
# * Artigos
# * SMS
# * Midias Sociais
# * Diario de Bordo
# * Livros
#
# - Desafios:
# * Transformar texto em voz
# * Transformar voz em texto
# * Feature Engineering: texto em dados númericos .

# %% [markdown]
# ## Natural Language Toolkit

# %% [markdown]
# - Lembra do Dataset? = Corpus ( texto que será minerado )
# - Conjunto de Corpus : Corpora
#
# A biblioteca  NLTK - ferramentas para trabalhar com texto, além de corpora de textos em diversos idiomas.

# %% [markdown]
# - Analisar Sentimentos
# - Nuvem de palavras
#
#
#
#
#
# ![image.png](attachment:image.png)
