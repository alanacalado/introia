# %%
print ('Alô mundo IA !')
# Out:
# Alô mundo IA !

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# %%
url = 'https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv'

# %%
# Carregar o DataFrame
df = pd.read_csv(url)

# %%
df.head(2)
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa

# %% [markdown]
# #### ![image.png](attachment:image.png)

# %%
# Mostrando a variedades de plantas
df['variety'].value_counts()
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # List Comprehension

# %%
# Aplicação do List Comprehension
# [] - Lista 
# Trocar o '.' por '_', boa prática para não bugar algumas funções
df.columns = [s.replace('.','_') for s in df.columns]

# %%
df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa

# %%
# pesquisa
# copia independente (copy()) - as alterações não afetam o df original 

df_setosa = df.query('variety == "Setosa"').copy()
df_virginica = df.query('variety == "Virginica"').copy()
df_versicolor = df.query('variety == "Versicolor"').copy()

print(df_setosa)
print(df_virginica)
print(df_versicolor)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# 13           4.3          3.0           1.1          0.1  Setosa
# 14           5.8          4.0           1.2          0.2  Setosa
# 15           5.7          4.4           1.5          0.4  Setosa
# 16           5.4          3.9           1.3          0.4  Setosa
# 17           5.1          3.5           1.4          0.3  Setosa
# 18           5.7          3.8           1.7          0.3  Setosa
# 19           5.1          3.8           1.5          0.3  Setosa
# 20           5.4          3.4           1.7          0.2  Setosa
# 21           5.1          3.7           1.5          0.4  Setosa
# 22           4.6          3.6           1.0          0.2  Setosa
# 23           5.1          3.3           1.7          0.5  Setosa
# 24           4.8          3.4           1.9          0.2  Setosa
# 25           5.0          3.0           1.6          0.2  Setosa
# 26           5.0          3.4           1.6          0.4  Setosa
# 27           5.2          3.5           1.5          0.2  Setosa
# 28           5.2          3.4           1.4          0.2  Setosa
# 29           4.7          3.2           1.6          0.2  Setosa
# 30           4.8          3.1           1.6          0.2  Setosa
# 31           5.4          3.4           1.5          0.4  Setosa
# 32           5.2          4.1           1.5          0.1  Setosa
# 33           5.5          4.2           1.4          0.2  Setosa
# 34           4.9          3.1           1.5          0.2  Setosa
# 35           5.0          3.2           1.2          0.2  Setosa
# 36           5.5          3.5           1.3          0.2  Setosa
# 37           4.9          3.6           1.4          0.1  Setosa
# 38           4.4          3.0           1.3          0.2  Setosa
# 39           5.1          3.4           1.5          0.2  Setosa
# 40           5.0          3.5           1.3          0.3  Setosa
# 41           4.5          2.3           1.3          0.3  Setosa
# 42           4.4          3.2           1.3          0.2  Setosa
# 43           5.0          3.5           1.6          0.6  Setosa
# 44           5.1          3.8           1.9          0.4  Setosa
# 45           4.8          3.0           1.4          0.3  Setosa
# 46           5.1          3.8           1.6          0.2  Setosa
# 47           4.6          3.2           1.4          0.2  Setosa
# 48           5.3          3.7           1.5          0.2  Setosa
# 49           5.0          3.3           1.4          0.2  Setosa
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 101           5.8          2.7           5.1          1.9  Virginica
# 74           6.4          2.9           4.3          1.3  Versicolor
# 75           6.6          3.0           4.4          1.4  Versicolor
# 76           6.8          2.8           4.8          1.4  Versicolor
# 77           6.7          3.0           5.0          1.7  Versicolor
# 78           6.0          2.9           4.5          1.5  Versicolor
# 79           5.7          2.6           3.5          1.0  Versicolor
# 80           5.5          2.4           3.8          1.1  Versicolor
# 81           5.5          2.4           3.7          1.0  Versicolor
# 82           5.8          2.7           3.9          1.2  Versicolor
# 83           6.0          2.7           5.1          1.6  Versicolor
# 84           5.4          3.0           4.5          1.5  Versicolor
# 85           6.0          3.4           4.5          1.6  Versicolor
# 86           6.7          3.1           4.7          1.5  Versicolor
# 87           6.3          2.3           4.4          1.3  Versicolor
# 88           5.6          3.0           4.1          1.3  Versicolor
# 89           5.5          2.5           4.0          1.3  Versicolor
# 90           5.5          2.6           4.4          1.2  Versicolor
# 91           6.1          3.0           4.6          1.4  Versicolor
# 92           5.8          2.6           4.0          1.2  Versicolor
# 93           5.0          2.3           3.3          1.0  Versicolor
# 94           5.6          2.7           4.2          1.3  Versicolor
# 95           5.7          3.0           4.2          1.2  Versicolor
# 96           5.7          2.9           4.2          1.3  Versicolor
# 97           6.2          2.9           4.3          1.3  Versicolor
# 98           5.1          2.5           3.0          1.1  Versicolor
# 99           5.7          2.8           4.1          1.3  Versicolor

# %%
# pesquisa
# copia independente (copy()) - as alterações não afetam o df original 

df_setosa = df.query('variety == "Setosa"').copy()
df_virginica = df.query('variety == "Virginica"').copy()
df_versicolor = df.query('variety == "Versicolor"').copy()

# Criar uma lista dos nomes das colunas de medidas
medidas = ['sepal_length','sepal_width','petal_length','petal_width']

# %%
print('Setosa')
# Out:
# Setosa

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ead\documents\gabi\semanatextmining\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib as plt

# %%
df_setosa[medidas].hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df_versicolor[medidas].hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df_virginica[medidas].hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %% [markdown]
# # Poder Preditivo

# %%
df.query('petal_length > 5')['variety'].value_counts()
# Out:
# variety
# Virginica     41
# Versicolor     1
# Name: count, dtype: int64

# %%
df.query('petal_length > 5')['variety'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # Inteligência Artificial

# %% [markdown]
# - Máquinas que imitam comportamento humano.
# - Esse conceito é geral (guarda-chuva)
# - Máquinas e softwares que tomam decisões e podem prever o futuro.
# - Máquinas inteligentes que podem executar desde tarefas simples de automação até vencer um humanoem uma partida de xadrez.

# %% [markdown]
# ## Aprendizado de Máquina

# %% [markdown]
# - Marchine Learning
# - Área dentro da IA
# - Pode ser visto como uma área dentro da inteligência artificial e se refere a técnicas para construir conhecimento (estimar funções) a partir de observações (0,1) - variáveis explicativas, varíavel target (alvo)

# %% [markdown]
# ## Aprendizado Profundo

# %% [markdown]
# - Redes Neurais
# - Deep Learning
# - Neurociência

# %% [markdown]
# ## Conclusão

# %% [markdown]
# ![image.png](attachment:image.png)
